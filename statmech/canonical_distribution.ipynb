# %%
import numpy as np 
import matplotlib.pyplot as plt

x = np.linspace(0,0.1,1000)
E = 0.001/x
y = np.exp(-E)
plt.plot(x, y)
# Out:
# <ipython-input-5-ec1cb459a933>:5: RuntimeWarning: divide by zero encountered in true_divide
#   E = 0.001/x
