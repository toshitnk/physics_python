# %%
import numpy as np
import matplotlib.pyplot as plt

x = np.linspace(-10, 10, 1000)
y = 1/np.tanh(x) - 1/x
plt.plot(x, y)
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

x = np.linspace(0,10, 1000)
y = np.exp ( (-x **2 ))

z = x ** 2 * y

plt.plot(x, y)

plt.show()


plt.plot(x, z)

plt.show()
